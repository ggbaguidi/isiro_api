# %%
# !pip install -q kagglehub xgboost optuna

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("naiyakhalid/flood-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/ggbaguidi/.cache/kagglehub/datasets/naiyakhalid/flood-prediction-dataset/versions/1

# %%
# List files in dataset
# !ls -l $path
# Out:
# total 2300
# -rw-rw-r-- 1 ggbaguidi ggbaguidi 2354496 Mar  5 13:20 flood.csv

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

from xgboost import XGBRegressor

import optuna

# %%
df = pd.read_csv(path + "/flood.csv")
df
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                     3                   8                6              6
# 1                     8                   4                5              7
# 2                     3                  10                4              1
# 3                     4                   4                2              7
# 4                     3                   7                5              2
# ...                 ...                 ...              ...            ...
# 49995                 3                   7                4              7
# 49996                 3                  10                3              8
# 49997                 4                   4                5              7
# 49998                 4                   5                4              4
# 49999                 4                   5                6              3
#
#        Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0                 4              4            6          2
# 1                 7              9            1          5
# 2                 7              5            4          7
# 3                 3              4            1          4
# 4                 5              8            5          2
# ...             ...            ...          ...        ...
# 49995             5              9            4          6
# 49996             3              3            4          4
# 49997             2              1            4          5
# 49998             6              3           10          2
# 49999             5              6            5          4
#
#        AgriculturalPractices  Encroachments  ...  DrainageSystems  \
# 0                          3              2  ...               10
# 1                          5              4  ...                9
# 2                          4              9  ...                7
# 3                          6              4  ...                4
# 4                          7              5  ...                7
# ...                      ...            ...  ...              ...
# 49995                     10              4  ...                7
# 49996                      3             11  ...                8
# 49997                      6              7  ...                4
# 49998                      6             11  ...                6
# 49999                      9             10  ...                2
#
#        CoastalVulnerability  Landslides  Watersheds  \
# 0                         7           4           2
# 1                         2           6           2
# 2                         4           4           8
# 3                         2           6           6
# 4                         6           5           3
# ...                     ...         ...         ...
# 49995                     3           8           8
# 49996                     6           3           6
# 49997                     6           4           1
# 49998                     3           4           7
# 49999                     4           4           5
#
#        DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                                3                4            3
# 1                                1                1            9
# 2                                6                1            8
# 3                                8                8            6
# 4                                3                4            4
# ...                            ...              ...          ...
# 49995                            6                1            5
# 49996                            4                4            2
# 49997                            5                1            6
# 49998                            6                2            4
# 49999                            6                7            8
#
#        InadequatePlanning  PoliticalFactors  FloodProbability
# 0                       2                 6             0.450
# 1                       1                 3             0.475
# 2                       3                 6             0.515
# 3                       6                10             0.520
# 4                       3                 4             0.475
# ...                   ...               ...               ...
# 49995                   4                 2             0.535
# 49996                   4                 5             0.510
# 49997                   4                 3             0.430
# 49998                   0                11             0.515
# 49999                  10                 7             0.580
#
# [50000 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MonsoonIntensity                 50000 non-null  int64
#  1   TopographyDrainage               50000 non-null  int64
#  2   RiverManagement                  50000 non-null  int64
#  3   Deforestation                    50000 non-null  int64
#  4   Urbanization                     50000 non-null  int64
#  5   ClimateChange                    50000 non-null  int64
#  6   DamsQuality                      50000 non-null  int64
#  7   Siltation                        50000 non-null  int64
#  8   AgriculturalPractices            50000 non-null  int64
#  9   Encroachments                    50000 non-null  int64
#  10  IneffectiveDisasterPreparedness  50000 non-null  int64
#  11  DrainageSystems                  50000 non-null  int64
#  12  CoastalVulnerability             50000 non-null  int64
#  13  Landslides                       50000 non-null  int64
#  14  Watersheds                       50000 non-null  int64
#  15  DeterioratingInfrastructure      50000 non-null  int64
#  16  PopulationScore                  50000 non-null  int64
#  17  WetlandLoss                      50000 non-null  int64
#  18  InadequatePlanning               50000 non-null  int64
#  19  PoliticalFactors                 50000 non-null  int64
#  20  FloodProbability                 50000 non-null  float64
# dtypes: float64(1), int64(20)
# memory usage: 8.0 MB

# %% [markdown]
# **1. Dataset Overview:**<br>
#     - The dataset contains 50,000 entries with 21 columns in total.<br>
#     - There are 20 feature columns and 1 target column (FloodProbability).<br><br>
# **2. Data Types:**<br>
#     - 20 columns are of type int64.<br>
#     - The target variable, FloodProbability, is of type float64.<br><br>
# **3. Data Quality:**<br>
#     - There are no null values in any column.<br>
#     - All features are numeric.<br><br>
# **4. Potential Analysis Approaches:** <br>
#     - Given continious nature of the data, regression techniques would be appropriate for predicting FloodProbability.<br>
#     - Correlation analysis can identify relationships between features and the target.<br>
#     - Feature importance analysis could reveal which factors have the strongest influence on flood probability.<br>

# %% [markdown]
# # Explanatory Data Analysis

# %% [markdown]
# ### 1. Histogram Analysis

# %%
# Remove 'FloodProbability' column from the columns list
columns = df.drop('FloodProbability', axis=1).columns
n_cols = 2
n_rows = int(np.ceil(len(columns) / n_cols))

# Create subplots
fig, axes = plt.subplots(nrows=n_rows, ncols=2, figsize=(9, n_rows * 3))
axes = axes.flatten()

# Plot histograms for each column except 'FloodProbability'
for i, column in enumerate(columns):
    ax = axes[i]
    col_data = df[column]
    bins = np.arange(col_data.min(), col_data.max() + 2)
    ax.hist(col_data, bins=bins, alpha=0.7, edgecolor='k')
    ax.set_title(f'Histogram of {column}')
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')
    ax.set_xticks(bins)
    
    # Summary statistics text
    summary_text = col_data.describe().apply(lambda x: f'{x:.2f}').to_string()
    ax.text(0.95, 0.95, summary_text, transform=ax.transAxes, fontsize=8,
            verticalalignment='top', horizontalalignment='right',
            bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

# Remove any unused subplots
for ax in axes[len(columns):]:
    fig.delaxes(ax)
    
plt.tight_layout()
plt.show()

# %%
# Create subplots
fig, ax = plt.subplots(figsize=(9, 6))
bins = np.linspace(df['FloodProbability'].min(), df['FloodProbability'].max(), 45) # min, max, bar count

# Plot FloodProbability
ax.hist(df['FloodProbability'], bins=bins, alpha=0.7, edgecolor='k')
ax.set_title(f'Histogram of Flood Probability')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_xticks(bins[::2])
ax.tick_params(axis='x', rotation=45)
    
# Summary statistics text
summary_text = df['FloodProbability'].describe().apply(lambda x: f'{x:.2f}').to_string()
ax.text(0.95, 0.95, summary_text, transform=ax.transAxes, fontsize=8,
        verticalalignment='top', horizontalalignment='right',
        bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.show()

# %% [markdown]
# ### 2. Correlation Analysis

# %%
fig, ax = plt.subplots(figsize=(9, 6))

# Plot Heatmap
corr_matrix = df.corr()
mask = np.abs(corr_matrix) > 0.2
sns.heatmap(corr_matrix, annot=True, cmap=sns.cubehelix_palette(as_cmap=True), mask=~mask, annot_kws={"size": 8})

plt.title('Correlation Heatmap (|r| > 0.2)')
plt.show()

# %% [markdown]
# **Conclusions**
# - All columns are roughly bell-shaped. This is acceptable, and the dataset doesn't strictly need transformation.
# - The correlations between individual features and Flood Probability appear to be relatively consistent, with no single feature showing a substantially stronger relationship than the others.

# %% [markdown]
# # Preprocessing

# %%
def preprocess(df):
    df = df.copy()
    
    X = df.drop('FloodProbability', axis=1)
    y = df['FloodProbability']
    
    return X, y

# %%
X, y = preprocess(df)

# %% [markdown]
# # Pipeline

# %%
def build_model(params=None):
    numerical_transformer = Pipeline(steps=[
        ('MinMax Scaler', MinMaxScaler())
    ])
    
    preprocessor = ColumnTransformer(transformers=[
        ('Numerical Transformer', numerical_transformer, X.select_dtypes(np.number).columns)
    ], remainder='passthrough')
    
    if params is None:
        xgb_model = XGBRegressor(random_state=42)
    else:
        xgb_model = XGBRegressor(random_state=42, **params)
        
    model = Pipeline(steps=[
        ('Preprocess', preprocessor),
        ('XGBModel', xgb_model)
    ])
    
    return model

# %% [markdown]
# # Train

# %% [markdown]
# ## Cross Validation

# %%
model = build_model()

cv_scores = cross_val_score(model, X, y, cv=5, scoring='neg_root_mean_squared_error')
cv_rmse = -cv_scores.mean()
print(f"Cross-validation RMSE: {cv_rmse}")
# Out:
# Cross-validation RMSE: 0.013377775099253853

# %% [markdown]
# ## Train Test Split & HyperParameter Optimization

# %%
def print_metrics(target, predictions):
    rmse = np.sqrt(mean_squared_error(target, predictions))
    r2 = r2_score(target, predictions)
    mae = mean_absolute_error(target, predictions)
    print(f'Root Mean Squarred Error: {rmse}\nR-squared (r^2): {r2}\nMean Absolute Error: {mae}')

# %%
X, y = preprocess(df)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, random_state=42)
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Numerical Transformer',
#                                                   Pipeline(steps=[('MinMax '
#                                                                    'Scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'Ineffecti...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=42, ...))])

# %%
predictions = model.predict(X_test)
print_metrics(y_test, predictions)
# Out:
# Root Mean Squarred Error: 0.013584748491394204
# R-squared (r^2): 0.9261235596294177
# Mean Absolute Error: 0.010802139900875092

# %% [markdown]
# ## HyperParameter Optimizing

# %%
X, y = preprocess(df)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=True, random_state=42) 
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.17, shuffle=True, random_state=42)

# %% [markdown]
# Splitted data to Train, Validation and Test sets
# - 75% Train Set
# - 15% Validation Set
# - 10% Test Set

# %%
def objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 1, 20),
        'learning_rate': trial.suggest_float('learning_rate', 1e-3, 1.0, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 2000),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
    }
    
    model = build_model(params)
    model.fit(X_train, y_train)
    
    preds = model.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, preds))
    return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-03-05 13:30:06,658] A new study created in memory with name: no-name-039e7315-0c04-4033-8639-fd39d28307d7
# [I 2025-03-05 13:30:14,143] Trial 0 finished with value: 0.018469777337049697 and parameters: {'max_depth': 14, 'learning_rate': 0.1984464162071847, 'n_estimators': 1858, 'min_child_weight': 7, 'subsample': 0.7455688840835843, 'colsample_bytree': 0.7270039536168158, 'gamma': 1.69048858576441e-08, 'reg_alpha': 9.722927907271044e-07, 'reg_lambda': 2.669645939027241e-07}. Best is trial 0 with value: 0.018469777337049697.
# [I 2025-03-05 13:30:25,948] Trial 1 finished with value: 0.005870561895087168 and parameters: {'max_depth': 6, 'learning_rate': 0.05358650349843421, 'n_estimators': 1922, 'min_child_weight': 7, 'subsample': 0.5854158544234243, 'colsample_bytree': 0.6348712685177063, 'gamma': 8.061942322887948e-06, 'reg_alpha': 1.5940941124178e-07, 'reg_lambda': 8.836151153649732e-07}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:30:31,720] Trial 2 finished with value: 0.032150216787179116 and parameters: {'max_depth': 19, 'learning_rate': 0.0038431403267510005, 'n_estimators': 530, 'min_child_weight': 4, 'subsample': 0.7909156790162577, 'colsample_bytree': 0.7343207757682166, 'gamma': 0.032467130495397525, 'reg_alpha': 3.455617824947122e-06, 'reg_lambda': 7.66597653675439e-06}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:30:35,318] Trial 3 finished with value: 0.009008169834490381 and parameters: {'max_depth': 6, 'learning_rate': 0.020388268289261696, 'n_estimators': 843, 'min_child_weight': 3, 'subsample': 0.7487745299102819, 'colsample_bytree': 0.9348949882642961, 'gamma': 1.1969670780979945e-05, 'reg_alpha': 3.7512259435000505e-08, 'reg_lambda': 0.07741996859677597}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:30:38,451] Trial 4 finished with value: 0.017359564657006395 and parameters: {'max_depth': 20, 'learning_rate': 0.020194332972560514, 'n_estimators': 1659, 'min_child_weight': 1, 'subsample': 0.5190557456685527, 'colsample_bytree': 0.8845198300241456, 'gamma': 0.11293039216467418, 'reg_alpha': 0.00014080064206328492, 'reg_lambda': 8.424737641502626e-07}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:30:56,085] Trial 5 finished with value: 0.016549094411819783 and parameters: {'max_depth': 12, 'learning_rate': 0.03130877005451517, 'n_estimators': 1226, 'min_child_weight': 5, 'subsample': 0.9015980835525089, 'colsample_bytree': 0.9343986304252068, 'gamma': 1.9031931402157716e-07, 'reg_alpha': 0.0030658446267852074, 'reg_lambda': 0.003680912772103766}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:33:52,240] Trial 6 finished with value: 0.021660387786815186 and parameters: {'max_depth': 15, 'learning_rate': 0.002074934956043743, 'n_estimators': 1369, 'min_child_weight': 5, 'subsample': 0.6253612406141122, 'colsample_bytree': 0.9790807302190263, 'gamma': 6.828402835572386e-07, 'reg_alpha': 2.0135220272556325e-08, 'reg_lambda': 2.799393969627775e-08}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:34:10,560] Trial 7 finished with value: 0.018026436286996777 and parameters: {'max_depth': 14, 'learning_rate': 0.04093331829352065, 'n_estimators': 1222, 'min_child_weight': 5, 'subsample': 0.8525429965131862, 'colsample_bytree': 0.9159865508382784, 'gamma': 2.736343066220796e-06, 'reg_alpha': 0.0019892466107746553, 'reg_lambda': 0.7975063474630707}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:35:26,739] Trial 8 finished with value: 0.01564823916552625 and parameters: {'max_depth': 19, 'learning_rate': 0.007485816603099951, 'n_estimators': 1818, 'min_child_weight': 5, 'subsample': 0.5959901761133963, 'colsample_bytree': 0.9694104446148111, 'gamma': 2.272686191044484e-06, 'reg_alpha': 1.239991688080825e-07, 'reg_lambda': 1.7023888307946254e-08}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:36:24,191] Trial 9 finished with value: 0.0280815549679673 and parameters: {'max_depth': 13, 'learning_rate': 0.0013469711865784924, 'n_estimators': 1692, 'min_child_weight': 3, 'subsample': 0.5868197577954893, 'colsample_bytree': 0.6036231232850846, 'gamma': 4.3743215604470725e-08, 'reg_alpha': 0.27247080498434395, 'reg_lambda': 5.322475501481489e-07}. Best is trial 1 with value: 0.005870561895087168.
# [I 2025-03-05 13:36:25,068] Trial 10 finished with value: 0.005653885241956211 and parameters: {'max_depth': 1, 'learning_rate': 0.9188512448906162, 'n_estimators': 437, 'min_child_weight': 10, 'subsample': 0.6539350964338474, 'colsample_bytree': 0.5015652687270278, 'gamma': 0.0010297032437225284, 'reg_alpha': 1.1962785656233122e-05, 'reg_lambda': 0.0001221488598606929}. Best is trial 10 with value: 0.005653885241956211.
# [I 2025-03-05 13:36:25,424] Trial 11 finished with value: 0.011807152351015454 and parameters: {'max_depth': 1, 'learning_rate': 0.6480419849039898, 'n_estimators': 125, 'min_child_weight': 10, 'subsample': 0.6694173492831265, 'colsample_bytree': 0.5073230860498522, 'gamma': 0.000927912864079313, 'reg_alpha': 1.1760894283665076e-05, 'reg_lambda': 0.00013636037898608723}. Best is trial 10 with value: 0.005653885241956211.
# [I 2025-03-05 13:36:27,658] Trial 12 finished with value: 0.003277121103769505 and parameters: {'max_depth': 1, 'learning_rate': 0.8024008641458918, 'n_estimators': 751, 'min_child_weight': 10, 'subsample': 0.5045349928823786, 'colsample_bytree': 0.5914826996874938, 'gamma': 0.0002719920357522294, 'reg_alpha': 5.4378596993210855e-05, 'reg_lambda': 0.00015702571950698644}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:28,915] Trial 13 finished with value: 0.004061050003674452 and parameters: {'max_depth': 1, 'learning_rate': 0.8322279569662981, 'n_estimators': 623, 'min_child_weight': 10, 'subsample': 0.5133374643551794, 'colsample_bytree': 0.5026393106971905, 'gamma': 0.0006488197367654367, 'reg_alpha': 6.557840560217088e-05, 'reg_lambda': 0.00019952356220554395}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:31,134] Trial 14 finished with value: 0.008330743553121753 and parameters: {'max_depth': 4, 'learning_rate': 0.25210495024922885, 'n_estimators': 801, 'min_child_weight': 8, 'subsample': 0.5002685513835705, 'colsample_bytree': 0.6025657877326281, 'gamma': 0.00027930072960193617, 'reg_alpha': 0.00022161844212146108, 'reg_lambda': 0.0016929280338951992}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:32,167] Trial 15 finished with value: 0.013822559943675134 and parameters: {'max_depth': 9, 'learning_rate': 0.21609320609499513, 'n_estimators': 641, 'min_child_weight': 9, 'subsample': 0.5266157596987763, 'colsample_bytree': 0.5537821521105929, 'gamma': 0.005416206194376356, 'reg_alpha': 0.010429148355804226, 'reg_lambda': 2.505067997264075e-05}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:33,201] Trial 16 finished with value: 0.009310701186164 and parameters: {'max_depth': 4, 'learning_rate': 0.4002219545411193, 'n_estimators': 251, 'min_child_weight': 8, 'subsample': 0.9721577790826756, 'colsample_bytree': 0.6606750352215424, 'gamma': 3.140730267811397e-05, 'reg_alpha': 0.061858766894407995, 'reg_lambda': 0.0006741503678072347}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:37,008] Trial 17 finished with value: 0.012577410727087443 and parameters: {'max_depth': 9, 'learning_rate': 0.10141673446113118, 'n_estimators': 977, 'min_child_weight': 10, 'subsample': 0.7065364238126445, 'colsample_bytree': 0.8470123386971544, 'gamma': 0.007553792569306259, 'reg_alpha': 0.0004614027257946968, 'reg_lambda': 0.006453366400481057}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:39,225] Trial 18 finished with value: 0.007926551720587755 and parameters: {'max_depth': 3, 'learning_rate': 0.9137101736798257, 'n_estimators': 692, 'min_child_weight': 8, 'subsample': 0.5602844799360124, 'colsample_bytree': 0.8096846007736901, 'gamma': 0.00017076887401110577, 'reg_alpha': 2.635650858761424e-05, 'reg_lambda': 0.02480617837274554}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:40,495] Trial 19 finished with value: 0.02865176785174548 and parameters: {'max_depth': 7, 'learning_rate': 0.10918627374990063, 'n_estimators': 335, 'min_child_weight': 9, 'subsample': 0.5435939043735066, 'colsample_bytree': 0.6803083510799532, 'gamma': 0.47381309600946964, 'reg_alpha': 0.0013534706664387393, 'reg_lambda': 9.4517637943904e-06}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:47,647] Trial 20 finished with value: 0.004230229927327314 and parameters: {'max_depth': 2, 'learning_rate': 0.3993000682731706, 'n_estimators': 1032, 'min_child_weight': 7, 'subsample': 0.8111684903212337, 'colsample_bytree': 0.543584514400944, 'gamma': 6.556761601326293e-05, 'reg_alpha': 1.6068401269260703e-06, 'reg_lambda': 0.00037656692156257625}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:50,474] Trial 21 finished with value: 0.004155648166629991 and parameters: {'max_depth': 2, 'learning_rate': 0.44249707623285317, 'n_estimators': 1016, 'min_child_weight': 7, 'subsample': 0.817918186913189, 'colsample_bytree': 0.5597634435181758, 'gamma': 6.016162874779369e-05, 'reg_alpha': 1.5594328436358745e-06, 'reg_lambda': 0.0004173437439690582}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:52,591] Trial 22 finished with value: 0.01120790772792985 and parameters: {'max_depth': 4, 'learning_rate': 0.4894332912546014, 'n_estimators': 908, 'min_child_weight': 9, 'subsample': 0.8672500661506537, 'colsample_bytree': 0.5638551927864796, 'gamma': 0.0010807275311158677, 'reg_alpha': 4.1419197193460004e-05, 'reg_lambda': 2.6691861999690552e-05}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:54,944] Trial 23 finished with value: 0.0036993135690127138 and parameters: {'max_depth': 1, 'learning_rate': 0.1162016494899681, 'n_estimators': 1206, 'min_child_weight': 10, 'subsample': 0.944170339193374, 'colsample_bytree': 0.5821652357448192, 'gamma': 0.005230739462917793, 'reg_alpha': 3.948712848889312e-07, 'reg_lambda': 0.0003066559727799394}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:56,962] Trial 24 finished with value: 0.0036707507054788806 and parameters: {'max_depth': 1, 'learning_rate': 0.11768890362542095, 'n_estimators': 1427, 'min_child_weight': 10, 'subsample': 0.9618157033947915, 'colsample_bytree': 0.6099507808284379, 'gamma': 0.006874854189379266, 'reg_alpha': 3.7228535100958537e-07, 'reg_lambda': 5.088008125331292e-05}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:36:59,237] Trial 25 finished with value: 0.009089809319587265 and parameters: {'max_depth': 5, 'learning_rate': 0.10376844194195929, 'n_estimators': 1434, 'min_child_weight': 9, 'subsample': 0.9980752906203539, 'colsample_bytree': 0.678857949070231, 'gamma': 0.006593196508785, 'reg_alpha': 2.672150160864991e-07, 'reg_lambda': 4.515711579586203e-06}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:37:02,702] Trial 26 finished with value: 0.014067622439096785 and parameters: {'max_depth': 8, 'learning_rate': 0.06268470993272621, 'n_estimators': 1213, 'min_child_weight': 10, 'subsample': 0.9429416167352352, 'colsample_bytree': 0.6178877105977649, 'gamma': 0.06812407896703362, 'reg_alpha': 1.4093097034878456e-08, 'reg_lambda': 0.014841411227365047}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:37:04,729] Trial 27 finished with value: 0.030090621169015366 and parameters: {'max_depth': 3, 'learning_rate': 0.14887340720796052, 'n_estimators': 1510, 'min_child_weight': 8, 'subsample': 0.9184991753478865, 'colsample_bytree': 0.7684396782781464, 'gamma': 0.8603527037546265, 'reg_alpha': 6.621166861200055e-06, 'reg_lambda': 3.035159908857321e-05}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:37:08,086] Trial 28 finished with value: 0.025406412508012396 and parameters: {'max_depth': 3, 'learning_rate': 0.007653705071914051, 'n_estimators': 1149, 'min_child_weight': 9, 'subsample': 0.9529112360574739, 'colsample_bytree': 0.7042594338215841, 'gamma': 0.024080235839179974, 'reg_alpha': 3.6668319823377263e-07, 'reg_lambda': 0.0013669403228145519}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:37:11,920] Trial 29 finished with value: 0.01821594714959614 and parameters: {'max_depth': 16, 'learning_rate': 0.2324561384925695, 'n_estimators': 1584, 'min_child_weight': 6, 'subsample': 0.8882457189866084, 'colsample_bytree': 0.5825474510725007, 'gamma': 0.0023603931324514688, 'reg_alpha': 6.253920341570572e-08, 'reg_lambda': 2.6124699868486696e-06}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:37:14,216] Trial 30 finished with value: 0.019024308376710302 and parameters: {'max_depth': 11, 'learning_rate': 0.0712188410772248, 'n_estimators': 1373, 'min_child_weight': 1, 'subsample': 0.7219512294054387, 'colsample_bytree': 0.6439121434782951, 'gamma': 0.18794669952701162, 'reg_alpha': 6.427099076908612e-07, 'reg_lambda': 3.60780404966892e-05}. Best is trial 12 with value: 0.003277121103769505.
# [I 2025-03-05 13:37:15,087] Trial 31 finished with value: 0.001790729244035245 and parameters: {'max_depth': 1, 'learning_rate': 0.2965903856547731, 'n_estimators': 628, 'min_child_weight': 10, 'subsample': 0.9948558741314778, 'colsample_bytree': 0.5277225469647617, 'gamma': 0.0002333976084782827, 'reg_alpha': 6.931342232813894e-05, 'reg_lambda': 0.00015024365199884938}. Best is trial 31 with value: 0.001790729244035245.
# [I 2025-03-05 13:37:16,354] Trial 32 finished with value: 0.00133304914334854 and parameters: {'max_depth': 1, 'learning_rate': 0.28918898275555344, 'n_estimators': 726, 'min_child_weight': 10, 'subsample': 0.979650968586769, 'colsample_bytree': 0.532067680379618, 'gamma': 0.00031688557102851656, 'reg_alpha': 2.2818754879998625e-06, 'reg_lambda': 8.633192181328431e-05}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:18,432] Trial 33 finished with value: 0.010764804294549254 and parameters: {'max_depth': 5, 'learning_rate': 0.30534879542377824, 'n_estimators': 755, 'min_child_weight': 9, 'subsample': 0.9784081709821183, 'colsample_bytree': 0.530241563193115, 'gamma': 0.0002191531734761684, 'reg_alpha': 2.0163539526277697e-06, 'reg_lambda': 6.354741548963344e-05}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:19,272] Trial 34 finished with value: 0.0049619099255701704 and parameters: {'max_depth': 2, 'learning_rate': 0.15083971411903457, 'n_estimators': 510, 'min_child_weight': 10, 'subsample': 0.9975196354731113, 'colsample_bytree': 0.6356272162317899, 'gamma': 2.085414847504097e-05, 'reg_alpha': 4.454148446922396e-06, 'reg_lambda': 1.0141153273726022e-05}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:21,745] Trial 35 finished with value: 0.017558489091398736 and parameters: {'max_depth': 6, 'learning_rate': 0.6084141119740276, 'n_estimators': 864, 'min_child_weight': 8, 'subsample': 0.9218339174925512, 'colsample_bytree': 0.5323580741685955, 'gamma': 0.02294979446753506, 'reg_alpha': 0.0006167654847129841, 'reg_lambda': 2.7388496445408572e-06}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:23,100] Trial 36 finished with value: 0.0048646080884752144 and parameters: {'max_depth': 2, 'learning_rate': 0.3189494668624607, 'n_estimators': 513, 'min_child_weight': 9, 'subsample': 0.7748519904036064, 'colsample_bytree': 0.7607943470778858, 'gamma': 6.713199428631161e-06, 'reg_alpha': 2.220752562769461e-05, 'reg_lambda': 0.0012384529095013845}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:25,061] Trial 37 finished with value: 0.008872253936826474 and parameters: {'max_depth': 5, 'learning_rate': 0.1736203720583741, 'n_estimators': 385, 'min_child_weight': 10, 'subsample': 0.8544920149841098, 'colsample_bytree': 0.5815759379034771, 'gamma': 0.0003984231176767406, 'reg_alpha': 0.00012609353743444084, 'reg_lambda': 6.395376794053625e-08}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:26,202] Trial 38 finished with value: 0.0066499483352246815 and parameters: {'max_depth': 3, 'learning_rate': 0.6028782405421924, 'n_estimators': 715, 'min_child_weight': 3, 'subsample': 0.9688735915189306, 'colsample_bytree': 0.6082059118155274, 'gamma': 0.00010503026092677327, 'reg_alpha': 5.178184366795969e-06, 'reg_lambda': 7.603195790602579e-05}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:29,977] Trial 39 finished with value: 0.025710044091372366 and parameters: {'max_depth': 1, 'learning_rate': 0.02312974767941918, 'n_estimators': 1099, 'min_child_weight': 6, 'subsample': 0.8891154707300255, 'colsample_bytree': 0.5261629869831594, 'gamma': 0.0026545221937371495, 'reg_alpha': 9.488681399476501e-08, 'reg_lambda': 2.0418181132155917e-07}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:47,537] Trial 40 finished with value: 0.01558548412504537 and parameters: {'max_depth': 17, 'learning_rate': 0.039708149387376594, 'n_estimators': 922, 'min_child_weight': 9, 'subsample': 0.8300666777530044, 'colsample_bytree': 0.702692292839385, 'gamma': 8.22217870942051e-06, 'reg_alpha': 0.011446179757461289, 'reg_lambda': 1.1093832114889832e-05}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:50,092] Trial 41 finished with value: 0.006101061147366037 and parameters: {'max_depth': 1, 'learning_rate': 0.08119838070967764, 'n_estimators': 1305, 'min_child_weight': 10, 'subsample': 0.9432112896741989, 'colsample_bytree': 0.5665991676006694, 'gamma': 0.014504423603370998, 'reg_alpha': 8.436840651466005e-07, 'reg_lambda': 0.00024518539866161146}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:52,218] Trial 42 finished with value: 0.004981258333200511 and parameters: {'max_depth': 2, 'learning_rate': 0.13628399101572478, 'n_estimators': 589, 'min_child_weight': 10, 'subsample': 0.9213443091103128, 'colsample_bytree': 0.5818655742077942, 'gamma': 0.0019915412453787042, 'reg_alpha': 3.990502427422817e-08, 'reg_lambda': 0.0008142888692012354}. Best is trial 32 with value: 0.00133304914334854.
# [I 2025-03-05 13:37:53,761] Trial 43 finished with value: 0.0012634011958641703 and parameters: {'max_depth': 1, 'learning_rate': 0.29663072395021434, 'n_estimators': 1946, 'min_child_weight': 10, 'subsample': 0.9714885295525179, 'colsample_bytree': 0.6293946708391971, 'gamma': 0.0005111127477701869, 'reg_alpha': 2.2117333610039007e-07, 'reg_lambda': 0.004088615751666836}. Best is trial 43 with value: 0.0012634011958641703.
# [I 2025-03-05 13:37:55,228] Trial 44 finished with value: 0.008309700555208603 and parameters: {'max_depth': 3, 'learning_rate': 0.2927459979483264, 'n_estimators': 1957, 'min_child_weight': 9, 'subsample': 0.9821198478782521, 'colsample_bytree': 0.6570012504852657, 'gamma': 0.00043992496591668096, 'reg_alpha': 1.5692538747034727e-07, 'reg_lambda': 0.0032867788449146306}. Best is trial 43 with value: 0.0012634011958641703.
# [I 2025-03-05 13:37:57,586] Trial 45 finished with value: 0.0076489355415770835 and parameters: {'max_depth': 4, 'learning_rate': 0.6232796357935254, 'n_estimators': 1745, 'min_child_weight': 10, 'subsample': 0.9591808752333706, 'colsample_bytree': 0.6237372358144836, 'gamma': 3.449557941621382e-05, 'reg_alpha': 7.692579519002496e-05, 'reg_lambda': 0.44438810609822804}. Best is trial 43 with value: 0.0012634011958641703.
# [I 2025-03-05 13:37:59,381] Trial 46 finished with value: 0.0007083614574881388 and parameters: {'max_depth': 1, 'learning_rate': 0.18798248424251818, 'n_estimators': 1895, 'min_child_weight': 4, 'subsample': 0.9024623493839159, 'colsample_bytree': 0.524829764703627, 'gamma': 0.0001280783809090578, 'reg_alpha': 1.2878350003358208e-05, 'reg_lambda': 0.09680213145297184}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:02,673] Trial 47 finished with value: 0.004693144969946013 and parameters: {'max_depth': 2, 'learning_rate': 0.20447210422407974, 'n_estimators': 1805, 'min_child_weight': 4, 'subsample': 0.9036716740473563, 'colsample_bytree': 0.525086922828669, 'gamma': 0.0001147799060126038, 'reg_alpha': 1.0824835221863412e-05, 'reg_lambda': 0.11762305676760594}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:20,052] Trial 48 finished with value: 0.012514812525941965 and parameters: {'max_depth': 6, 'learning_rate': 0.36894744113009986, 'n_estimators': 1900, 'min_child_weight': 4, 'subsample': 0.6134096787220127, 'colsample_bytree': 0.5132965305162168, 'gamma': 1.7961923779524706e-06, 'reg_alpha': 2.160118411482341e-05, 'reg_lambda': 0.08452639086622157}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:22,372] Trial 49 finished with value: 0.012638920165851652 and parameters: {'max_depth': 4, 'learning_rate': 0.9502164977487623, 'n_estimators': 825, 'min_child_weight': 2, 'subsample': 0.7678176365674337, 'colsample_bytree': 0.5453926449673405, 'gamma': 1.3835187988672496e-05, 'reg_alpha': 2.8484606138881124e-06, 'reg_lambda': 0.011478414619490004}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:28,481] Trial 50 finished with value: 0.031533729397210546 and parameters: {'max_depth': 1, 'learning_rate': 0.010332722125739456, 'n_estimators': 1642, 'min_child_weight': 4, 'subsample': 0.9876924778512555, 'colsample_bytree': 0.5066655347412964, 'gamma': 0.0009674946539444742, 'reg_alpha': 0.0003911807672743828, 'reg_lambda': 0.031164247525899906}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:34,391] Trial 51 finished with value: 0.0008696655267757541 and parameters: {'max_depth': 1, 'learning_rate': 0.22368599974031592, 'n_estimators': 1862, 'min_child_weight': 3, 'subsample': 0.9310135396892596, 'colsample_bytree': 0.5990939437466609, 'gamma': 0.00024506617359972195, 'reg_alpha': 4.6631952289539455e-05, 'reg_lambda': 0.26201757289810107}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:37,807] Trial 52 finished with value: 0.005273939424327087 and parameters: {'max_depth': 2, 'learning_rate': 0.24580292751338303, 'n_estimators': 1846, 'min_child_weight': 3, 'subsample': 0.9326650723935992, 'colsample_bytree': 0.5943588926430213, 'gamma': 0.0002363387340744615, 'reg_alpha': 0.0002114140213864959, 'reg_lambda': 0.3060728795957052}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:42,974] Trial 53 finished with value: 0.0056828593208408315 and parameters: {'max_depth': 3, 'learning_rate': 0.521602554041366, 'n_estimators': 1886, 'min_child_weight': 2, 'subsample': 0.8751425181160956, 'colsample_bytree': 0.5567655659751213, 'gamma': 6.848073542792852e-05, 'reg_alpha': 6.768675523813564e-05, 'reg_lambda': 0.194234647895179}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:48,878] Trial 54 finished with value: 0.002171846601119423 and parameters: {'max_depth': 1, 'learning_rate': 0.7546748735538066, 'n_estimators': 1983, 'min_child_weight': 2, 'subsample': 0.9132779867948304, 'colsample_bytree': 0.5486493491190682, 'gamma': 0.0004200586263941755, 'reg_alpha': 3.8158561965222345e-05, 'reg_lambda': 0.0423544214398044}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:38:53,673] Trial 55 finished with value: 0.001134268402291859 and parameters: {'max_depth': 1, 'learning_rate': 0.19403425915037387, 'n_estimators': 1991, 'min_child_weight': 2, 'subsample': 0.9045749645588893, 'colsample_bytree': 0.5402675499083311, 'gamma': 0.0005013080230686113, 'reg_alpha': 1.1724268972416762e-05, 'reg_lambda': 0.053511420924103735}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:00,278] Trial 56 finished with value: 0.005033060588644942 and parameters: {'max_depth': 2, 'learning_rate': 0.17577628747916904, 'n_estimators': 1999, 'min_child_weight': 1, 'subsample': 0.8984150591223579, 'colsample_bytree': 0.5199253751449711, 'gamma': 0.0013690451106562463, 'reg_alpha': 7.726095115137661e-06, 'reg_lambda': 0.47104283437433137}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:04,167] Trial 57 finished with value: 0.023896168416733667 and parameters: {'max_depth': 13, 'learning_rate': 0.33883883176397583, 'n_estimators': 1727, 'min_child_weight': 2, 'subsample': 0.8446121532719212, 'colsample_bytree': 0.5006271196425859, 'gamma': 0.00014494577402823786, 'reg_alpha': 1.6611601462570294e-05, 'reg_lambda': 0.00409041746185999}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:07,072] Trial 58 finished with value: 0.00815003469144817 and parameters: {'max_depth': 1, 'learning_rate': 0.04970070996127932, 'n_estimators': 1787, 'min_child_weight': 3, 'subsample': 0.9723474310581495, 'colsample_bytree': 0.5399294403249881, 'gamma': 1.1160590825403074e-08, 'reg_alpha': 1.0776140441262382e-06, 'reg_lambda': 0.90673228079208}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:10,218] Trial 59 finished with value: 0.006157746387397972 and parameters: {'max_depth': 4, 'learning_rate': 0.1987324972444123, 'n_estimators': 1648, 'min_child_weight': 5, 'subsample': 0.8720433465030574, 'colsample_bytree': 0.5690713857023052, 'gamma': 3.549730975081355e-05, 'reg_alpha': 3.662188610698586e-06, 'reg_lambda': 0.12020888786426698}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:12,807] Trial 60 finished with value: 0.00516119053828887 and parameters: {'max_depth': 3, 'learning_rate': 0.08000425985438318, 'n_estimators': 1925, 'min_child_weight': 3, 'subsample': 0.9391160084368811, 'colsample_bytree': 0.7887803490212478, 'gamma': 0.0006079180119448635, 'reg_alpha': 0.00014828489680158765, 'reg_lambda': 0.06606309640493203}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:15,066] Trial 61 finished with value: 0.002052440501017411 and parameters: {'max_depth': 1, 'learning_rate': 0.7397515252483324, 'n_estimators': 1970, 'min_child_weight': 2, 'subsample': 0.9092657205181504, 'colsample_bytree': 0.5528789579677916, 'gamma': 0.0003513043116606915, 'reg_alpha': 3.586430762178792e-05, 'reg_lambda': 0.041708301719139675}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:17,502] Trial 62 finished with value: 0.005399555887465258 and parameters: {'max_depth': 2, 'learning_rate': 0.2673151404393976, 'n_estimators': 1830, 'min_child_weight': 2, 'subsample': 0.9995555690709209, 'colsample_bytree': 0.5678637921058863, 'gamma': 7.709209980365509e-05, 'reg_alpha': 3.8889222235738004e-05, 'reg_lambda': 0.016346139400409687}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:19,361] Trial 63 finished with value: 0.0038450889887867105 and parameters: {'max_depth': 1, 'learning_rate': 0.38169709428934884, 'n_estimators': 1914, 'min_child_weight': 4, 'subsample': 0.9613766383216806, 'colsample_bytree': 0.5421223133129874, 'gamma': 0.003420076377101284, 'reg_alpha': 1.0294649993056683e-05, 'reg_lambda': 0.008038016309509724}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:39:22,316] Trial 64 finished with value: 0.0061234572505360204 and parameters: {'max_depth': 2, 'learning_rate': 0.4613253026480693, 'n_estimators': 1753, 'min_child_weight': 2, 'subsample': 0.9287229403173121, 'colsample_bytree': 0.5945961954817609, 'gamma': 0.0006495909719310209, 'reg_alpha': 0.00026615704807084103, 'reg_lambda': 0.21567288416183406}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:42:36,263] Trial 65 finished with value: 0.024595757072849275 and parameters: {'max_depth': 20, 'learning_rate': 0.002890248757905777, 'n_estimators': 1586, 'min_child_weight': 1, 'subsample': 0.9023912121300025, 'colsample_bytree': 0.6241519084196457, 'gamma': 0.00027911999842705385, 'reg_alpha': 1.7389946513492996e-05, 'reg_lambda': 0.047389976826969826}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:42:39,645] Trial 66 finished with value: 0.003350639123965911 and parameters: {'max_depth': 1, 'learning_rate': 0.5056624689947677, 'n_estimators': 1994, 'min_child_weight': 3, 'subsample': 0.9473283372053933, 'colsample_bytree': 0.5262093318465471, 'gamma': 0.00014882360156615027, 'reg_alpha': 0.6919654887914901, 'reg_lambda': 0.0027841672879475874}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:42:44,565] Trial 67 finished with value: 0.004150556726178029 and parameters: {'max_depth': 3, 'learning_rate': 0.13858710519688805, 'n_estimators': 1855, 'min_child_weight': 3, 'subsample': 0.9824811751887564, 'colsample_bytree': 0.8760957883731904, 'gamma': 6.03760337698701e-08, 'reg_alpha': 0.0006545982933816777, 'reg_lambda': 0.019985075150240405}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:42:44,957] Trial 68 finished with value: 0.014603056316960504 and parameters: {'max_depth': 1, 'learning_rate': 0.26927347305002947, 'n_estimators': 176, 'min_child_weight': 6, 'subsample': 0.8011252174226723, 'colsample_bytree': 0.5550662988684569, 'gamma': 0.0014643346999933526, 'reg_alpha': 2.0450395681620762e-06, 'reg_lambda': 0.15215915442243516}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:42:49,327] Trial 69 finished with value: 0.02039190781281608 and parameters: {'max_depth': 7, 'learning_rate': 0.7255722209822038, 'n_estimators': 1689, 'min_child_weight': 5, 'subsample': 0.9535789139098709, 'colsample_bytree': 0.7299331959390114, 'gamma': 5.039476708019674e-05, 'reg_alpha': 0.00010502120581646794, 'reg_lambda': 0.006054394732784574}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:42:55,546] Trial 70 finished with value: 0.00866520088848065 and parameters: {'max_depth': 5, 'learning_rate': 0.17050936501419378, 'n_estimators': 1945, 'min_child_weight': 1, 'subsample': 0.8835037201681835, 'colsample_bytree': 0.5163754524328967, 'gamma': 0.0006634486298116376, 'reg_alpha': 0.0011598481563271914, 'reg_lambda': 0.4624571624572228}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:08,464] Trial 71 finished with value: 0.0021334505319219182 and parameters: {'max_depth': 1, 'learning_rate': 0.7269786683026266, 'n_estimators': 1984, 'min_child_weight': 2, 'subsample': 0.9149516593005933, 'colsample_bytree': 0.5480503725573811, 'gamma': 0.00037982144998058564, 'reg_alpha': 3.982161738679687e-05, 'reg_lambda': 0.03777769880886802}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:18,613] Trial 72 finished with value: 0.006143766203195857 and parameters: {'max_depth': 2, 'learning_rate': 0.9788264309759188, 'n_estimators': 1888, 'min_child_weight': 2, 'subsample': 0.9086248199689826, 'colsample_bytree': 0.5761956640574959, 'gamma': 0.00024257352678541964, 'reg_alpha': 2.9931221554533873e-05, 'reg_lambda': 0.05297687415274791}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:20,745] Trial 73 finished with value: 0.008210770795337125 and parameters: {'max_depth': 3, 'learning_rate': 0.41371879069006773, 'n_estimators': 1789, 'min_child_weight': 2, 'subsample': 0.8578113053672951, 'colsample_bytree': 0.5351752519797778, 'gamma': 0.00042573091437310537, 'reg_alpha': 5.7508246268006366e-05, 'reg_lambda': 0.03137720087806807}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:22,881] Trial 74 finished with value: 0.004569809097625981 and parameters: {'max_depth': 2, 'learning_rate': 0.2171473045273647, 'n_estimators': 1946, 'min_child_weight': 3, 'subsample': 0.8361828495318637, 'colsample_bytree': 0.599829834210529, 'gamma': 0.00011367898466069595, 'reg_alpha': 8.093364522422769e-06, 'reg_lambda': 0.08432103599914823}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:24,589] Trial 75 finished with value: 0.0014217449904099962 and parameters: {'max_depth': 1, 'learning_rate': 0.5458577499847482, 'n_estimators': 1860, 'min_child_weight': 1, 'subsample': 0.9306662038474612, 'colsample_bytree': 0.5560729302684584, 'gamma': 1.8248085480855398e-05, 'reg_alpha': 1.4913640215015993e-05, 'reg_lambda': 0.24772483997256292}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:25,047] Trial 76 finished with value: 0.0030124911989338914 and parameters: {'max_depth': 1, 'learning_rate': 0.31648447815669317, 'n_estimators': 454, 'min_child_weight': 1, 'subsample': 0.933709524828619, 'colsample_bytree': 0.5577963759796439, 'gamma': 3.0230034985520566e-06, 'reg_alpha': 3.0498505096398544e-06, 'reg_lambda': 0.6953595856983469}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:26,136] Trial 77 finished with value: 0.007321479464238678 and parameters: {'max_depth': 4, 'learning_rate': 0.514299266547833, 'n_estimators': 583, 'min_child_weight': 1, 'subsample': 0.9651450728821935, 'colsample_bytree': 0.5868084882865247, 'gamma': 1.8126845939679287e-05, 'reg_alpha': 1.4215568655663944e-05, 'reg_lambda': 0.2561501496616958}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:41,360] Trial 78 finished with value: 0.04144646345926901 and parameters: {'max_depth': 3, 'learning_rate': 0.0011118042377661877, 'n_estimators': 1881, 'min_child_weight': 1, 'subsample': 0.9856870315151979, 'colsample_bytree': 0.5014443953742463, 'gamma': 5.062750221158027e-05, 'reg_alpha': 4.949452773530715e-06, 'reg_lambda': 0.00011183389381258652}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:43,099] Trial 79 finished with value: 0.0035933352589245914 and parameters: {'max_depth': 2, 'learning_rate': 0.09005326794996003, 'n_estimators': 1575, 'min_child_weight': 7, 'subsample': 0.6777380995499394, 'colsample_bytree': 0.5721343340196497, 'gamma': 5.679156306345991e-06, 'reg_alpha': 8.160132304006802e-05, 'reg_lambda': 0.0006080984327993673}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:44,546] Trial 80 finished with value: 0.016535069766630064 and parameters: {'max_depth': 10, 'learning_rate': 0.2412410788456663, 'n_estimators': 682, 'min_child_weight': 4, 'subsample': 0.9290037030237083, 'colsample_bytree': 0.6512703310048384, 'gamma': 0.00017532750766898183, 'reg_alpha': 2.419468980164556e-07, 'reg_lambda': 0.002080664849259472}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:47,137] Trial 81 finished with value: 0.0010576951651747235 and parameters: {'max_depth': 1, 'learning_rate': 0.711876476074653, 'n_estimators': 1832, 'min_child_weight': 2, 'subsample': 0.8913282611812947, 'colsample_bytree': 0.9958499284142464, 'gamma': 2.701271226618987e-05, 'reg_alpha': 3.174337898097449e-05, 'reg_lambda': 0.011072613891560902}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:43:52,237] Trial 82 finished with value: 0.001424543178950022 and parameters: {'max_depth': 1, 'learning_rate': 0.586252200891887, 'n_estimators': 1849, 'min_child_weight': 2, 'subsample': 0.8862157553072276, 'colsample_bytree': 0.9860560892009731, 'gamma': 1.932785386538344e-05, 'reg_alpha': 2.4625799610853397e-05, 'reg_lambda': 0.012665090178485064}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:00,127] Trial 83 finished with value: 0.003322424457579279 and parameters: {'max_depth': 2, 'learning_rate': 0.43637873625671014, 'n_estimators': 1769, 'min_child_weight': 3, 'subsample': 0.952837946015845, 'colsample_bytree': 0.9903810049101069, 'gamma': 2.7726162827605703e-05, 'reg_alpha': 2.2972867444270083e-05, 'reg_lambda': 0.01293437981502879}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:01,449] Trial 84 finished with value: 0.0015517454519000154 and parameters: {'max_depth': 1, 'learning_rate': 0.5569213155412366, 'n_estimators': 1698, 'min_child_weight': 1, 'subsample': 0.8874840077575392, 'colsample_bytree': 0.9601049556964664, 'gamma': 4.927615884035066e-06, 'reg_alpha': 0.00013972600830959478, 'reg_lambda': 1.6490806799184396e-05}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:16,799] Trial 85 finished with value: 0.0022210236786994113 and parameters: {'max_depth': 2, 'learning_rate': 0.5509419885635617, 'n_estimators': 1705, 'min_child_weight': 1, 'subsample': 0.888179154793136, 'colsample_bytree': 0.9570987972532472, 'gamma': 5.590251215659591e-07, 'reg_alpha': 0.00014206680963354715, 'reg_lambda': 1.3350334961482306e-05}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:25,241] Trial 86 finished with value: 0.0012483457219411762 and parameters: {'max_depth': 1, 'learning_rate': 0.6395357555690262, 'n_estimators': 1841, 'min_child_weight': 1, 'subsample': 0.858678126713215, 'colsample_bytree': 0.960837981046874, 'gamma': 9.44220954871082e-06, 'reg_alpha': 5.95823851303038e-07, 'reg_lambda': 0.009084858209315257}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:29,706] Trial 87 finished with value: 0.004823054242888647 and parameters: {'max_depth': 3, 'learning_rate': 0.8565394473894422, 'n_estimators': 1814, 'min_child_weight': 2, 'subsample': 0.8623479681879722, 'colsample_bytree': 0.9994031934227773, 'gamma': 1.0819241773561266e-05, 'reg_alpha': 1.3276952852773664e-06, 'reg_lambda': 0.008306043354013814}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:35,733] Trial 88 finished with value: 0.0007166277046299924 and parameters: {'max_depth': 1, 'learning_rate': 0.3856339963745028, 'n_estimators': 1851, 'min_child_weight': 1, 'subsample': 0.8723043348075717, 'colsample_bytree': 0.9290908873575543, 'gamma': 2.1740866253999676e-05, 'reg_alpha': 5.998962599548986e-07, 'reg_lambda': 0.005543068999563898}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:39,866] Trial 89 finished with value: 0.030126852311653195 and parameters: {'max_depth': 18, 'learning_rate': 0.3739228577241525, 'n_estimators': 1913, 'min_child_weight': 1, 'subsample': 0.8417601639556058, 'colsample_bytree': 0.9196162355149976, 'gamma': 3.661767044824819e-06, 'reg_alpha': 4.381852031852531e-07, 'reg_lambda': 0.005310285256834853}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:46,473] Trial 90 finished with value: 0.0024967779190185296 and parameters: {'max_depth': 2, 'learning_rate': 0.4362898120409385, 'n_estimators': 1509, 'min_child_weight': 1, 'subsample': 0.8271804107908851, 'colsample_bytree': 0.9509842303721484, 'gamma': 1.0461151915314614e-05, 'reg_alpha': 5.575951840627402e-07, 'reg_lambda': 0.02521566118836478}. Best is trial 46 with value: 0.0007083614574881388.
# [I 2025-03-05 13:44:50,118] Trial 91 finished with value: 0.0006200065112065437 and parameters: {'max_depth': 1, 'learning_rate': 0.3278012875614896, 'n_estimators': 1842, 'min_child_weight': 2, 'subsample': 0.8907034057886325, 'colsample_bytree': 0.9762506350180927, 'gamma': 2.055333065634767e-05, 'reg_alpha': 7.971128211651291e-08, 'reg_lambda': 0.11344887586793251}. Best is trial 91 with value: 0.0006200065112065437.
# [I 2025-03-05 13:44:53,279] Trial 92 finished with value: 0.0007093748720708914 and parameters: {'max_depth': 1, 'learning_rate': 0.3589238108008242, 'n_estimators': 1840, 'min_child_weight': 1, 'subsample': 0.8766230432020998, 'colsample_bytree': 0.9361113897224287, 'gamma': 1.2714271776709249e-06, 'reg_alpha': 2.703719011577973e-08, 'reg_lambda': 0.13768081875185045}. Best is trial 91 with value: 0.0006200065112065437.
# [I 2025-03-05 13:44:58,765] Trial 93 finished with value: 0.0005652240282267968 and parameters: {'max_depth': 1, 'learning_rate': 0.17567889224841096, 'n_estimators': 1803, 'min_child_weight': 2, 'subsample': 0.8686777898430629, 'colsample_bytree': 0.9390404290306837, 'gamma': 1.5527094736906153e-06, 'reg_alpha': 2.444952252404091e-08, 'reg_lambda': 0.10483000268516034}. Best is trial 93 with value: 0.0005652240282267968.
# [I 2025-03-05 13:45:03,415] Trial 94 finished with value: 0.0022196159038047653 and parameters: {'max_depth': 2, 'learning_rate': 0.33989596780642867, 'n_estimators': 1816, 'min_child_weight': 2, 'subsample': 0.8751460717388139, 'colsample_bytree': 0.9279035739022328, 'gamma': 1.7534304640151862e-06, 'reg_alpha': 2.4009376170325538e-08, 'reg_lambda': 0.10602581512699615}. Best is trial 93 with value: 0.0005652240282267968.
# [I 2025-03-05 13:45:05,382] Trial 95 finished with value: 0.0014311498369116535 and parameters: {'max_depth': 1, 'learning_rate': 0.12266958363446977, 'n_estimators': 1744, 'min_child_weight': 2, 'subsample': 0.8180349522078103, 'colsample_bytree': 0.8909499526077062, 'gamma': 8.243741474723326e-07, 'reg_alpha': 5.515818497553649e-08, 'reg_lambda': 0.06451106929768444}. Best is trial 93 with value: 0.0005652240282267968.
# [I 2025-03-05 13:45:08,215] Trial 96 finished with value: 0.0032289423312603033 and parameters: {'max_depth': 2, 'learning_rate': 0.17728693880964766, 'n_estimators': 1639, 'min_child_weight': 1, 'subsample': 0.897936353264436, 'colsample_bytree': 0.9404468215732202, 'gamma': 2.1162526427185363e-07, 'reg_alpha': 8.158962982463275e-08, 'reg_lambda': 0.3524770874812679}. Best is trial 93 with value: 0.0005652240282267968.
# [I 2025-03-05 13:45:29,825] Trial 97 finished with value: 0.003541923174105558 and parameters: {'max_depth': 3, 'learning_rate': 0.22174446649430646, 'n_estimators': 1777, 'min_child_weight': 2, 'subsample': 0.8544452002543108, 'colsample_bytree': 0.8928015824539357, 'gamma': 1.584731170394468e-07, 'reg_alpha': 2.2815880368339366e-08, 'reg_lambda': 0.021699425637641278}. Best is trial 93 with value: 0.0005652240282267968.
# [I 2025-03-05 13:45:36,222] Trial 98 finished with value: 0.024364826776007136 and parameters: {'max_depth': 1, 'learning_rate': 0.014436982961262876, 'n_estimators': 1928, 'min_child_weight': 3, 'subsample': 0.8717011734870544, 'colsample_bytree': 0.9062431440231921, 'gamma': 9.87177410891079e-07, 'reg_alpha': 1.4472230152041934e-08, 'reg_lambda': 0.12061216660465753}. Best is trial 93 with value: 0.0005652240282267968.
# [I 2025-03-05 13:45:40,523] Trial 99 finished with value: 0.000337389980099403 and parameters: {'max_depth': 1, 'learning_rate': 0.25693019849663806, 'n_estimators': 1870, 'min_child_weight': 1, 'subsample': 0.8957827376791213, 'colsample_bytree': 0.9744259846552944, 'gamma': 1.5889547056550087e-06, 'reg_alpha': 1.892148874327654e-07, 'reg_lambda': 0.17253920615523893}. Best is trial 99 with value: 0.000337389980099403.

# %%
best_params = study.best_params

# %%
model = build_model(best_params)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print_metrics(y_test, predictions)
# Out:
# Root Mean Squarred Error: 0.00024062741983028684
# R-squared (r^2): 0.9999766295665925
# Mean Absolute Error: 0.00015814719295501728

# %%
MODEL_PATH = './../checkpoints/xgboost_model.pkl'
# Import Pickle
import pickle

# Save the model to a file
with open(MODEL_PATH, 'wb') as file:
    pickle.dump(model, file)

# %%
# Load the model using Pickle
with open(MODEL_PATH, 'rb') as file:
    loaded_model_pickle = pickle.load(file)

# %%
predictions = loaded_model_pickle.predict(X_test)
print_metrics(y_test, predictions)
# Out:
# Root Mean Squarred Error: 0.00024062741983028684
# R-squared (r^2): 0.9999766295665925
# Mean Absolute Error: 0.00015814719295501728
